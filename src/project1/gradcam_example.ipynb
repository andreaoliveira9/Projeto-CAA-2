# %% [markdown]
# # GradCAM Example
#
# This notebook demonstrates how to use the simplified GradCAM implementation for explaining model predictions on image classification tasks.

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import cv2

# Force TensorFlow to use CPU only (optional)
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

from gradcam_utils import GradCAMUtils
from gradcam_main import parse_args, run_single_image_analysis, run_model_comparison, run_single_model_analysis

# %%
DATASET_DIR = "dataset_organized"
MODELS_DIR = "trained_models"
OUTPUT_DIR = "output"
ANALYSIS_TYPE = "image"
IMAGE_PATH = "dataset_organized/test/cardboard/cardboard2.jpg"
MODEL = "all" # "resnet", "vgg", "densenet", "all"

WASTE_CLASS_NAMES = ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %%
gradcam_utils = GradCAMUtils(
    class_names=WASTE_CLASS_NAMES,
    img_size=150,
    dataset_dir=DATASET_DIR,
    models_dir=MODELS_DIR,
    output_dir=OUTPUT_DIR
)

# %%
run_single_image_analysis(gradcam_utils, MODEL, IMAGE_PATH, display=True)
# Out:
# Running GradCAM analysis on image: dataset_organized/test/cardboard/cardboard2.jpg
# Loading model: resnet_model_es.h5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Successfully loaded resnet_model_es.h5
# Loading model: vgg_model.h5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Successfully loaded vgg_model.h5
# Loading model: densenet121_model.h5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Successfully loaded densenet121_model.h5
# Loaded 3 models successfully.
# Detected class: cardboard (index: 0)
#
# Comparing GradCAM results across multiple models...
# ...
