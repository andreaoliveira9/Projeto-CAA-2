# %% [markdown]
# # LIME Example
#
# This notebook demonstrates how to use the simplified LIME implementation for explaining model predictions on image classification tasks.

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import cv2

# Force TensorFlow to use CPU only (optional)
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

from lime_utils import LIMEUtils
from lime_main import analyze_single_image

# %%
DATASET_DIR = "dataset_organized"
MODELS_DIR = "trained_models"
OUTPUT_DIR = "output"
ANALYSIS_TYPE = "image"
IMAGE_PATH = "dataset_organized/test/cardboard/cardboard2.jpg"
MODEL = "densenet" # "resnet", "vgg", "densenet", "all"

WASTE_CLASS_NAMES = ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %%
lime_utils = LIMEUtils(
    class_names=WASTE_CLASS_NAMES,
    img_size=150,
    dataset_dir=DATASET_DIR,
    models_dir=MODELS_DIR,
    output_dir=OUTPUT_DIR
)

# %%
analyze_single_image(lime_utils, MODEL, IMAGE_PATH, num_features=100, display=True)
# Out:
# Analyzing image: dataset_organized/test/cardboard/cardboard2.jpg
# Loading model: densenet121_model.h5
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Successfully loaded densenet121_model.h5
# Loaded 1 models successfully.
# Detected class: cardboard (index: 0)
#
# Applying LIME to image with model: densenet121_model.h5
#   0%|          | 0/1000 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# ...
